# %%
library(tidyverse)
library(repr)
library(tidymodels)
options(repr.matrix.max.rows = 6)
library(ggplot2)
library(cowplot)
# Out:
# Error in library(tidymodels): there is no package called ‘tidymodels’
# Traceback:
#
# 1. library(tidymodels)

# %% [markdown]
# ## Doses administered: Reports from provinces and territories
#
# Information on doses administered by dose number and vaccine product is provided by provinces and territories every 4 weeks.
#
# In the last 4 weeks, the majority of doses administered were dose 4 or more.
#
# Data may not be available for some report weeks because:
# - data was not submitted for that week (see data availability)
# - data quality assurance resulted in negative values
# - Data on doses administered should not be used as a substitute for vaccination coverage estimates.
# - National data by dose number is incomplete as:
# - data on dose 5+ were not available for Nunavut
# - data by dose number were not available for Quebec prior to March 13, 2022, and so appears as "Not reported"
# - national data excluded doses administered by federal organizations
# - Information is subject to change. Numbers may differ in provincial and territorial reports due to the timing of updates and the suppression of values less than 5 for 7 provinces and territories (see limitations).
# - Where possible, the number of doses administered includes all doses administered by a province or territory, regardless of where the person receiving the vaccine lives. However, the number of vaccine doses administered may be overestimated due to - -  provincial and territorial partners including doses administered to their residents by other provinces and territories.
# - Use caution when comparing data over time. Reporting delays can result in artificial increases in counts while ongoing data quality assurance activities can result in unexpected decreases.

# %%
data <- read_csv("abc/vaccination-administration-bydosenumber_grouped.csv")
data<-data|>
rename(numtotal_dose5_admin= 'numtotal_dose5+_admin')

head(data)
# Out:
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Rows: 9217 Columns: 31
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr   (4): prename, prfname, vaccine_group, product_name
# dbl  (26): pruid, numtotal_totaldoses_admin, numtotal_dose1_admin, numtotal_...
# date  (1): week_end
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   week_end   pruid prename                   prfname
# 1 2020-12-19  1    Canada                    Canada
# 2 2020-12-19  1    Canada                    Canada
# 3 2020-12-19  1    Canada                    Canada
# 4 2020-12-19  1    Canada                    Canada
# 5 2020-12-19 10    Newfoundland and Labrador Terre-Neuve-et-Labrador
# 6 2020-12-19 10    Newfoundland and Labrador Terre-Neuve-et-Labrador
#   vaccine_group
# 1 Pfizer-BioNTech Comirnaty formulations
# 2 Total
# 3 Unknown
# 4 Unknown
# 5 Pfizer-BioNTech Comirnaty formulations
# 6 Total
#   product_name                                        numtotal_totaldoses_admin
# 1 Pfizer-BioNTech Comirnaty (ages 12 years and older) 12360
# 2 Total                                               12362
# 3 Not reported                                            0
# 4 Unknown                                                 2
# 5 Pfizer-BioNTech Comirnaty (ages 12 years and older)   972
# 6 Total                                                 972
#   numtotal_dose1_admin numtotal_dose2_admin numtotal_dose3_admin ⋯
# 1 7632                 0                    NA                   ⋯
# 2 7634                 0                    NA                   ⋯
# 3    0                 0                    NA                   ⋯
# 4    2                 0                    NA                   ⋯
# 5  972                 0                    NA                   ⋯
# 6  972                 0                    NA                   ⋯
#   num2weekdelta_dose3 num2weekdelta_dose4 num2weekdelta_dose5+
# 1 NA                  NA                  NA
# 2 NA                  NA                  NA
# 3 NA                  NA                  NA
# 4 NA                  NA                  NA
# 5 NA                  NA                  NA
# 6 NA                  NA                  NA
#   num2weekdelta_notreported num4weekdelta_dose1 num4weekdelta_dose2
# 1 NA                        NA                  NA
# 2 NA                        NA                  NA
# 3 NA                        NA                  NA
# 4 NA                        NA                  NA
# 5 NA                        NA                  NA
# 6 NA                        NA                  NA
#   num4weekdelta_dose3 num4weekdelta_dose4 num4weekdelta_dose5+
# 1 NA                  NA                  NA
# 2 NA                  NA                  NA
# 3 NA                  NA                  NA
# 4 NA                  NA                  NA
# 5 NA                  NA                  NA
# 6 NA                  NA                  NA
#   num4weekdelta_notreported
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
data_canada<- data|>
filter(product_name=="Total")|>
filter(prename=="Canada")
head(data_canada)
# Out:
#   week_end   pruid prename prfname vaccine_group product_name
# 1 2020-12-19 1     Canada  Canada  Total         Total
# 2 2020-12-26 1     Canada  Canada  Total         Total
# 3 2021-01-02 1     Canada  Canada  Total         Total
# 4 2021-01-09 1     Canada  Canada  Total         Total
# 5 2021-01-16 1     Canada  Canada  Total         Total
# 6 2021-01-23 1     Canada  Canada  Total         Total
#   numtotal_totaldoses_admin numtotal_dose1_admin numtotal_dose2_admin
# 1  12362                      7634                   0
# 2  46156                     28940                   0
# 3  82512                     54207                   0
# 4 221866                    134067                4521
# 5 591669                    419138               26748
# 6 834796                    556675               59294
#   numtotal_dose3_admin ⋯ num2weekdelta_dose3 num2weekdelta_dose4
# 1 NA                   ⋯ NA                  NA
# 2 NA                   ⋯ NA                  NA
# 3 NA                   ⋯ NA                  NA
# 4 NA                   ⋯ NA                  NA
# 5 NA                   ⋯ NA                  NA
# 6 NA                   ⋯ NA                  NA
#   num2weekdelta_dose5+ num2weekdelta_notreported num4weekdelta_dose1
# 1 NA                       NA                    NA
# 2 NA                       NA                    NA
# 3 NA                    23577                    NA
# 4 NA                       NA                    NA
# 5 NA                   117478                    NA
# 6 NA                       NA                    NA
#   num4weekdelta_dose2 num4weekdelta_dose3 num4weekdelta_dose4
# 1 NA                  NA                  NA
# 2 NA                  NA                  NA
# 3 NA                  NA                  NA
# 4 NA                  NA                  NA
# 5 NA                  NA                  NA
# 6 NA                  NA                  NA
#   num4weekdelta_dose5+ num4weekdelta_notreported
# 1 NA                   NA
# 2 NA                   NA
# 3 NA                   NA
# 4 NA                   NA
# 5 NA                   NA
# 6 NA                   NA

# %% [markdown]
# ## The original cleaned data

# %%
data2<-data_canada |>
select(- prename, - prfname, - pruid, - product_name)|>
    select(week_end:numtotal_dose5_admin)
head(data2)
tail(data2)
# Out:
#   week_end   vaccine_group numtotal_totaldoses_admin numtotal_dose1_admin
# 1 2020-12-19 Total          12362                      7634
# 2 2020-12-26 Total          46156                     28940
# 3 2021-01-02 Total          82512                     54207
# 4 2021-01-09 Total         221866                    134067
# 5 2021-01-16 Total         591669                    419138
# 6 2021-01-23 Total         834796                    556675
#   numtotal_dose2_admin numtotal_dose3_admin numtotal_dose4_admin
# 1     0                NA                   NA
# 2     0                NA                   NA
# 3     0                NA                   NA
# 4  4521                NA                   NA
# 5 26748                NA                   NA
# 6 59294                NA                   NA
#   numtotal_dose5_admin
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA
#   week_end   vaccine_group numtotal_totaldoses_admin numtotal_dose1_admin
# 1 2022-08-14 Total         87302043                  32234627
# 2 2022-09-11 Total         88341273                  32315048
# 3 2022-10-09 Total         90338953                  32355602
# 4 2022-11-06 Total         93124368                  32394301
# 5 2022-12-04 Total         95254108                  32448101
# 6 2023-01-01 Total         96326455                  32486260
#   numtotal_dose2_admin numtotal_dose3_admin numtotal_dose4_admin
# 1 30924700             19017041             5087687
# 2 30960196             19166631             5671410
# 3 30999132             19300918             6802850
# 4 31048389             19455006             8191316
# 5 31095248             19616957             9236002
# 6 31126255             19712010             9703248
#   numtotal_dose5_admin
# 1   37988
# 2  227988
# 3  880451
# 4 2035356
# 5 2857800
# 6 3298682

# %% [markdown]
# Normilized to days data

# %% [markdown]
# Normilized to days data

# %%
ex_data<- data2|>
select(week_end, numtotal_totaldoses_admin)
#ex_data
min(ex_data$week_end)
# Out:
# [1] "2020-12-19"

# %%
df2 <- data.frame(date = seq(as.Date("2020-12-19"), as.Date("2023-01-01"), by = "day"))
df2
# Out:
#     date
# 1   2020-12-19
# 2   2020-12-20
# 3   2020-12-21
# 4   2020-12-22
# 5   2020-12-23
# 6   2020-12-24
# 7   2020-12-25
# 8   2020-12-26
# 9   2020-12-27
# 10  2020-12-28
# 11  2020-12-29
# 12  2020-12-30
# 13  2020-12-31
# 14  2021-01-01
# 15  2021-01-02
# 16  2021-01-03
# 17  2021-01-04
# 18  2021-01-05
# 19  2021-01-06
# 20  2021-01-07
# 21  2021-01-08
# 22  2021-01-09
# 23  2021-01-10
# 24  2021-01-11
# 25  2021-01-12
# 26  2021-01-13
# 27  2021-01-14
# 28  2021-01-15
# 29  2021-01-16
# 30  2021-01-17
# ⋮   ⋮
# 715 2022-12-03
# 716 2022-12-04
# 717 2022-12-05
# 718 2022-12-06
# 719 2022-12-07
# 720 2022-12-08
# 721 2022-12-09
# 722 2022-12-10
# 723 2022-12-11
# 724 2022-12-12
# 725 2022-12-13
# 726 2022-12-14
# 727 2022-12-15
# 728 2022-12-16
# 729 2022-12-17
# 730 2022-12-18
# 731 2022-12-19
# 732 2022-12-20
# 733 2022-12-21
# 734 2022-12-22
# 735 2022-12-23
# 736 2022-12-24
# 737 2022-12-25
# 738 2022-12-26
# 739 2022-12-27
# 740 2022-12-28
# 741 2022-12-29
# 742 2022-12-30
# 743 2022-12-31
# 744 2023-01-01

# %%
newdata<- data2|>
    mutate(days=as.numeric(week_end)-18615)|>
    select(-week_end)

# %%
newnewdata <- newdata|>
#mutate(days=days)|>
mutate(total=as.vector(numtotal_totaldoses_admin))|>
mutate(dose1=as.vector(numtotal_dose1_admin))|>
mutate(dose2=as.vector(numtotal_dose2_admin))|>
mutate(dose3=as.vector(numtotal_dose3_admin))|>
mutate(dose4=as.vector(numtotal_dose4_admin))|>
mutate(dose5=as.vector(numtotal_dose5_admin))|>
select(-numtotal_totaldoses_admin,-numtotal_dose5_admin,-numtotal_dose4_admin,-numtotal_dose3_admin,-numtotal_dose2_admin,-numtotal_dose1_admin)
head(newnewdata)
# Out:
#   vaccine_group days total  dose1  dose2 dose3 dose4 dose5
# 1 Total          0    12362   7634     0 NA    NA    NA
# 2 Total          7    46156  28940     0 NA    NA    NA
# 3 Total         14    82512  54207     0 NA    NA    NA
# 4 Total         21   221866 134067  4521 NA    NA    NA
# 5 Total         28   591669 419138 26748 NA    NA    NA
# 6 Total         35   834796 556675 59294 NA    NA    NA

# %% [markdown]
# Using `newnewdata` to compelete the analysis

# %%
na_row_total<- nrow(newnewdata[is.na(newnewdata$total),])
na_row_total
na_row_1<- nrow(newnewdata[is.na(newnewdata$dose1),])
na_row_1
na_row_2<- nrow(newnewdata[is.na(newnewdata$dose2),])
na_row_2
na_row_3<- nrow(newnewdata[is.na(newnewdata$dose3),])
na_row_3
na_row_4<- nrow(newnewdata[is.na(newnewdata$dose4),])
na_row_4
na_row_5<- nrow(newnewdata[is.na(newnewdata$dose5),])
na_row_5
# Out:
# [1] 0
# [1] 0
# [1] 0
# [1] 16
# [1] 16
# [1] 16

# %% [raw]
# ggplot(newnewdata, aes(x=days,y=dose3))
#
# sa1<- nls(dose3~c*days^z, data=newnewdata, start=c(c=1750000, z=0.27))
# sa1
#
# ggplot(newnewdata, aes(x=days,y=dose3))
#
# #sa2<-lm(log(dose3)~log(days), data=newnewdata)
# #sa2

# %% [raw]
# newnewdata<-newnewdata|>
# mutate(days=as.factor(days))|>
# group_by(days)|>
# newnewdata

# %% [markdown]
# ## dose 1

# %%
options(repr.plot.width = 12, repr.plot.height = 7)

x<-newnewdata$days
y<-newnewdata$dose1
#plot(y~x,xlim=c(0,1000))

bbb <- nls(y ~ height/(1 + exp((xmid - x)/scal)),
                           start = list(xmid = 100, scal = 10, height = 5000000))
#bbb
aaa<- coef(bbb)
earlyx<-c(-300:1000)
ypred<-aaa[3]/(1 + exp((aaa[1] - earlyx)/aaa[2]))

#plot1<- plot(ypred~earlyx)+
#plot(y~x,xlim=c(0,1000))+
#lines(x,predict(bbb))+
#title("dose 1")

#plot1

    df <- data.frame(x = earlyx, y = ypred)
    
df<-df|>mutate(x=earlyx+18615)
df <- df |> mutate(x = as.Date(x, origin = "2020-12-19"))
    # create a ggplot object with the data
    plot_obj <- ggplot(data = df, aes(x = x, y = ypred)) +
      geom_point() +
      labs(x = "Year", y = "Number of doses administered") #+
#      facet_wrap(~ input$dose, nrow = 1)
plot_obj
# Out:
# plot without title

# %% [markdown]
# ## the graph looks wired

# %% [markdown]
# ## dose 2

# %%
x<-newnewdata$days
y<-newnewdata$dose2
#plot(y~x)

options(repr.plot.width = 12, repr.plot.height = 7)
bbb<-nls(y ~ height/(1 + exp((xmid - x)/scal)),
                           start = list(xmid = 100, scal = 10, height = 5000000))
#bbb
aaa<- coef(bbb)
earlyx<-c(0:1000)
ypred<-aaa[3]/(1 + exp((coef(bbb)[1] - earlyx)/coef(bbb)[2]))
#ypred


    df <- data.frame(x = earlyx, y = ypred)
    
df<-df|>mutate(x=earlyx+18615)
df <- df |> mutate(x = as.Date(x, origin = "2020-12-19"))
    # create a ggplot object with the data
    plot_obj <- ggplot(data = df, aes(x = x, y = ypred)) +
      geom_point() +
      labs(x = "Year", y = "Number of doses administered") #+
#      facet_wrap(~ input$dose, nrow = 1)
plot_obj
#predict(bbb)
# Out:
# plot without title

# %% [markdown]
# ## dose 3

# %%
newnewdata3<-newnewdata|>filter(!is.na(dose3))

# %%
x<-newnewdata3$days
y<-newnewdata3$dose3
plot(y~x)

options(repr.plot.width = 12, repr.plot.height = 7)
bbb<-nls(y ~ height/(1 + exp((xmid - x)/scal)),
                           start = list(xmid = 400, scal = 10, height = 5000000))
#bbb
aaa<- coef(bbb)
earlyx<-c(0:1000)
ypred<-aaa[3]/(1 + exp((coef(bbb)[1] - earlyx)/coef(bbb)[2]))
#ypred
    df <- data.frame(x = earlyx, y = ypred)
    
df<-df|>mutate(x=earlyx+18615)
df <- df |> mutate(x = as.Date(x, origin = "2020-12-19"))
    # create a ggplot object with the data
    plot_obj <- ggplot(data = df, aes(x = x, y = ypred)) +
      geom_point() +
      labs(x = "Year", y = "Number of doses administered") #+
#      facet_wrap(~ input$dose, nrow = 1)
plot_obj
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## dose 4

# %%
newnewdata4<-newnewdata|>filter(!is.na(dose4))
head(newnewdata4)
# Out:
#   vaccine_group days total    dose1    dose2   dose3 dose4 dose5
# 1 Total         112   8145392  5466319  803183 0     0     0
# 2 Total         119  10129352  6870045  899865 0     0     0
# 3 Total         126  12157691  8359605  968719 0     0     0
# 4 Total         133  13908535  9670367 1019308 0     0     0
# 5 Total         140  16031695 11233974 1078081 0     0     0
# 6 Total         147  18652595 13139059 1188775 0     0     0

# %%
x<-newnewdata4$days
y<-newnewdata4$dose4 
plot(y~x)

options(repr.plot.width = 12, repr.plot.height = 7)
bbb<-nls(y ~ height/(1 + exp((xmid - x)/scal)),
                           start = list(xmid = 600, scal = 10, height = 5000000))
#bbb
aaa<- coef(bbb)
earlyx<-c(0:1000)
ypred<-aaa[3]/(1 + exp((coef(bbb)[1] - earlyx)/coef(bbb)[2]))
#ypred
    df <- data.frame(x = earlyx, y = ypred)
    
df<-df|>mutate(x=earlyx+18615)
df <- df |> mutate(x = as.Date(x, origin = "2020-12-19"))
    # create a ggplot object with the data
    plot_obj <- ggplot(data = df, aes(x = x, y = ypred)) +
      geom_point() +
      labs(x = "Year", y = "Number of doses administered") #+
#      facet_wrap(~ input$dose, nrow = 1)
plot_obj
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## dose 5+

# %%
newnewdata5<-newnewdata|>filter(!is.na(dose5))
head(newnewdata5)
nrow(newnewdata5)
#ggplot(newnewdata5, aes(x=days,y=dose5))+
#geom_point(aes(color=age))
# Out:
#   vaccine_group days total    dose1    dose2   dose3 dose4 dose5
# 1 Total         112   8145392  5466319  803183 0     0     0
# 2 Total         119  10129352  6870045  899865 0     0     0
# 3 Total         126  12157691  8359605  968719 0     0     0
# 4 Total         133  13908535  9670367 1019308 0     0     0
# 5 Total         140  16031695 11233974 1078081 0     0     0
# 6 Total         147  18652595 13139059 1188775 0     0     0
# [1] 64

# %% [markdown]
# ### only 63 days of data for this dose

# %%
x<-newnewdata5$days
y<-newnewdata5$dose5
#plot(y~x)

options(repr.plot.width = 12, repr.plot.height = 7)
bbb<-nls(y ~ height/(1 + exp((xmid - x)/scal)), 
                           start = list(xmid = 640, scal = 10, height = 5000000))
#bbb
aaa<- coef(bbb)
earlyx<-c(-300:1000)
ypred<-aaa[3]/(1 + exp((coef(bbb)[1] - earlyx)/aaa[2]))
#ypred
    df <- data.frame(x = earlyx, y = ypred)
    





df<-df|>mutate(x=earlyx+18615)
df <- df |> mutate(x = as.Date(x, origin = "2020-12-19"))
    # create a ggplot object with the data
    plot_obj <- ggplot(data = df, aes(x = x, y = ypred)) +
      geom_point() +
      labs(x = "Year", y = "Number of doses administered") #+
#      facet_wrap(~ input$dose, nrow = 1)
plot_obj
# Out:
# plot without title

# %%
library(shiny)
library(ggplot2)
library(nls2)
library(plotly)


data<-read.csv("/Users/kia/Desktop/data_vaccine/vaccination-administration-bydosenumber2.csv")
#install.packages("vctrs")

library("tidyverse")
#install.packages("tidymodels")
#install.packages("ggplot2")
#install.packages("cowplot")

library(repr)
library(tidymodels)
options(repr.matrix.max.rows = 6)
library(cowplot)



data<-data|>
  rename(numtotal_dose5_admin= 'numtotal_dose5._admin')
data_canada<- data|>
  filter(product_name=="Total")|>
  filter(prename=="Canada")
data2<-data_canada |>
  select(- prename, - prfname, - pruid, - product_name)|>
  select(week_end:numtotal_dose5_admin)
data2 <- data2 %>%
  mutate(week_end = as.Date(week_end)) %>%
  mutate(days = as.numeric(week_end) - 18615)
newdata<- data2|>
  select(-week_end)
newnewdata <- newdata|>
  mutate(total=as.vector(numtotal_totaldoses_admin))|>
  mutate(dose1=as.vector(numtotal_dose1_admin))|>
  mutate(dose2=as.vector(numtotal_dose2_admin))|>
  mutate(dose3=as.vector(numtotal_dose3_admin))|>
  mutate(dose4=as.vector(numtotal_dose4_admin))|>
  mutate(dose5=as.vector(numtotal_dose5_admin))|>
  select(-numtotal_totaldoses_admin,-numtotal_dose5_admin,-numtotal_dose4_admin,-numtotal_dose3_admin,-numtotal_dose2_admin,-numtotal_dose1_admin)
options(repr.plot.width = 12, repr.plot.height = 7)

###df2 <- data.frame(date = seq(as.Date("2020-12-19"), as.Date("2023-01-01"), by = "year"))

newnewdata4<-newnewdata|>filter(!is.na(dose4))
newnewdata5<-newnewdata|>filter(!is.na(dose5))
# Define UI
ui <- fluidPage(
  titlePanel("My Plot"),
  sidebarLayout(
    radioButtons("dose",
                 "Vaccine Dose",
                 choices = c("Dose 1","Dose 2","Dose 3","Dose 4","Dose 5+"),
                 selected="Dose 1"),
 ###   sliderInput("date", "Choose Date:", 
###                min = min(df2$date), max = max(df2$date), 
###                value = min(df2$date), timeFormat="%Y-%m-%d"),
    mainPanel(
      plotOutput("myplot")
    )
  )
)


# Define server
server <- function(input, output) {
  # Load your data
 
  
  # Define function to create the plot
  output$myplot <- renderPlot({
    # generate bins based on input$bins from ui.R
    if(input$dose == "Dose 1"){y <- as.numeric(newnewdata$dose1)
    x <- as.numeric(newnewdata$days)
    abc<-100}
    if(input$dose == "Dose 2"){y <- as.numeric(newnewdata$dose2)
    x <- as.numeric(newnewdata$days)
    abc<-100}
    if(input$dose == "Dose 3"){y <- as.numeric(newnewdata$dose3)
    x <- as.numeric(newnewdata$days)
    abc<-400}
    if(input$dose == "Dose 4"){y <- as.numeric(newnewdata4$dose4)
    x <- as.numeric(newnewdata4$days)
    abc<-600}
    if(input$dose == "Dose 5+"){y <- as.numeric(newnewdata5$dose5)
    x <- as.numeric(newnewdata5$days)
    abc<-640}
    
    bbb <- nls(y ~ height/(1 + exp((xmid - x)/scal)),
               start = list(xmid = abc, scal = 10, height = 5000000))
    aaa <- coef(bbb)
    earlyx <- seq(-300, 1000, by = 1)
    ypred <- aaa[3]/(1 + exp((aaa[1] - earlyx)/aaa[2]))
   
   # plot_obj <- plot(ypred ~ earlyx, ylim=c(0,30000000), xlab="Year")
    df <- data.frame(x = earlyx, y = ypred)
    
    df<-df|>mutate(x=earlyx+18615)
    df <- df |> mutate(x = as.Date(x, origin = "2020-12-19"))
    
    # create a ggplot object with the data
    plot_obj <- ggplot(data = df, aes(x = x, y = ypred)) +
      geom_point() +
      labs(x = "Year", y = "Number of doses administered")
   # plot_obj <- lines(x, predict(bbb))
   # plot_obj <- title(input$dose)
    #plot_obj <-  plot_ly(x = df$x, y = df$ypred, type = "scatter", mode = "lines") %>%
      #layout(xaxis = list(title = "Year"), yaxis = list(title = "Doses Administered")) %>%
      #add_annotations(text = "y: {y}", xref = "paper", yref = "paper",
     #                 x = 1.05, y = 0, showarrow = FALSE) %>%
    #  highlight(on = "plotly_hover", hoverinfo = "text")
    
    return(plot_obj)
  })
}


# Run the app
shinyApp(ui, server)
# Out:
# Error in library(nls2): there is no package called ‘nls2’
# Traceback:
#
# 1. library(nls2)
