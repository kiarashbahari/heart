# %%
library(tidyverse)
library(repr)
library(tidymodels)
options(repr.matrix.max.rows = 6)
library(ggplot2)
library(cowplot)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   1.0.0
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Error in library(tidymodels): there is no package called ‘tidymodels’
# Traceback:
#
# 1. library(tidymodels)

# %%
data <- read_csv("data/vaccination-coverage-byAgeAndSex-overTimeDownload-2.csv")
head(data)
# Out:
# Rows: 77952 Columns: 18
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (13): prename, prfname, sex, age, numtotal_atleast1dose, numtotal_parti...
# dbl   (4): pruid, numtotal_additional, numtotal_2nd_additional, numtotal_rec...
# date  (1): week_end
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   pruid prename prfname week_end   sex       age      numtotal_atleast1dose
# 1 1     Canada  Canada  2020-12-19 All sexes 0–15     2
# 2 1     Canada  Canada  2020-12-19 All sexes 16–69    11766
# 3 1     Canada  Canada  2020-12-19 All sexes 70–74    174
# 4 1     Canada  Canada  2020-12-19 All sexes 75–79    85
# 5 1     Canada  Canada  2020-12-19 All sexes 80+      335
# 6 1     Canada  Canada  2020-12-19 All sexes All ages 12368
#   numtotal_partially numtotal_fully numtotal_additional numtotal_2nd_additional
# ...

# %%
data_allsex_canada<- data|>
filter(prename=="Canada")|>
filter(sex=="All sexes")|>
mutate(numtotal_atleast1dose=as.numeric(numtotal_atleast1dose))|>
mutate(numtotal_fully=as.numeric(numtotal_fully))|>
mutate(numtotal_additional=as.numeric(numtotal_additional))|>
mutate(numtotal_partially=as.numeric(numtotal_partially))

data2<-data_allsex_canada |> 
    select(week_end:numtotal_recent_fullyoradditional, -sex)

# %% [markdown]
# # filtering for all ages

# %%
data2<- data2 |> filter(age=="All ages")
head(data2)
# Out:
#   week_end   age      numtotal_atleast1dose numtotal_partially numtotal_fully
# 1 2020-12-19 All ages  12368                 12368                 0
# 2 2020-12-26 All ages  46180                 46180                 0
# 3 2021-01-02 All ages  82530                 82530                 0
# 4 2021-01-09 All ages 217393                212866              4527
# 5 2021-01-16 All ages 564976                538207             26769
# 6 2021-01-23 All ages 775546                716237             59309
#   numtotal_additional numtotal_2nd_additional numtotal_recent_fullyoradditional
# 1 NA                  NA                      NA
# 2 NA                  NA                      NA
# 3 NA                  NA                      NA
# 4 NA                  NA                      NA
# 5 NA                  NA                      NA
# 6 NA                  NA                      NA

# %% [markdown]
# # numtotal_partially (first dose?)

# %%
plot(data2$numtotal_partially~data2$week_end)
# Out:
# plot without title

# %% [markdown]
# # numtotal_fully (2nd dose?)

# %%
plot(data2$numtotal_fully~data2$week_end)
# Out:
# plot without title

# %% [markdown]
# # numtotal_additional (3rd dose?)

# %%
plot(data2$numtotal_additional~data2$week_end)
# Out:
# plot without title

# %% [markdown]
# # numtotal_2nd_additional (4th dose?)

# %%
plot(data2$numtotal_2nd_additional~data2$week_end)
# Out:
# plot without title
