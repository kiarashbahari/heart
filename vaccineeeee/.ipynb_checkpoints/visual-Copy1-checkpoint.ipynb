# %%
library(tidyverse)
library(repr)
library(tidymodels)
options(repr.matrix.max.rows = 6)
library(ggplot2)
library(cowplot)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.8     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Error in library(tidymodels): there is no package called ‘tidymodels’
# Traceback:
#
# 1. library(tidymodels)

# %% [markdown]
# ## Doses administered: Reports from provinces and territories
#
# Information on doses administered by dose number and vaccine product is provided by provinces and territories every 4 weeks.
#
# In the last 4 weeks, the majority of doses administered were dose 4 or more.
#
# Data may not be available for some report weeks because:
# - data was not submitted for that week (see data availability)
# - data quality assurance resulted in negative values
# - Data on doses administered should not be used as a substitute for vaccination coverage estimates.
# - National data by dose number is incomplete as:
# - data on dose 5+ were not available for Nunavut
# - data by dose number were not available for Quebec prior to March 13, 2022, and so appears as "Not reported"
# - national data excluded doses administered by federal organizations
# - Information is subject to change. Numbers may differ in provincial and territorial reports due to the timing of updates and the suppression of values less than 5 for 7 provinces and territories (see limitations).
# - Where possible, the number of doses administered includes all doses administered by a province or territory, regardless of where the person receiving the vaccine lives. However, the number of vaccine doses administered may be overestimated due to - -  provincial and territorial partners including doses administered to their residents by other provinces and territories.
# - Use caution when comparing data over time. Reporting delays can result in artificial increases in counts while ongoing data quality assurance activities can result in unexpected decreases.

# %%
data <- read_csv("abc/chr.csv")
data<-data|>
rename(numtotal_dose5_admin= 'numtotal_dose5+_admin')

head(data)
# Out:
# Warning message:
# “One or more parsing issues, see `problems()` for details”
# Rows: 8503 Columns: 30
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr   (3): prename, prfname, product_name
# dbl  (26): pruid, numtotal_totaldoses_admin, numtotal_dose1_admin, numtotal_...
# date  (1): week_end
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   week_end   pruid prename                   prfname
# 1 2020-12-19  1    Canada                    Canada
# 2 2020-12-19  1    Canada                    Canada
# 3 2020-12-19  1    Canada                    Canada
# 4 2020-12-19  1    Canada                    Canada
# 5 2020-12-19 10    Newfoundland and Labrador Terre-Neuve-et-Labrador
# 6 2020-12-19 10    Newfoundland and Labrador Terre-Neuve-et-Labrador
#   product_name                                        numtotal_totaldoses_admin
# 1 Not reported                                            0
# 2 Pfizer-BioNTech Comirnaty (ages 12 years and older) 12360
# 3 Total                                               12362
# 4 Unknown                                                 2
# 5 Not reported                                            0
# 6 Pfizer-BioNTech Comirnaty (ages 12 years and older)   972
#   numtotal_dose1_admin numtotal_dose2_admin numtotal_dose3_admin
# 1    0                 0                    NA
# 2 7632                 0                    NA
# 3 7634                 0                    NA
# 4    2                 0                    NA
# 5    0                 0                    NA
# 6  972                 0                    NA
#   numtotal_dose4_admin ⋯ num2weekdelta_dose3 num2weekdelta_dose4
# 1 NA                   ⋯ NA                  NA
# 2 NA                   ⋯ NA                  NA
# 3 NA                   ⋯ NA                  NA
# 4 NA                   ⋯ NA                  NA
# 5 NA                   ⋯ NA                  NA
# 6 NA                   ⋯ NA                  NA
#   num2weekdelta_dose5+ num2weekdelta_notreported num4weekdelta_dose1
# 1 NA                   NA                        NA
# 2 NA                   NA                        NA
# 3 NA                   NA                        NA
# 4 NA                   NA                        NA
# 5 NA                   NA                        NA
# 6 NA                   NA                        NA
#   num4weekdelta_dose2 num4weekdelta_dose3 num4weekdelta_dose4
# 1 NA                  NA                  NA
# 2 NA                  NA                  NA
# 3 NA                  NA                  NA
# 4 NA                  NA                  NA
# 5 NA                  NA                  NA
# 6 NA                  NA                  NA
#   num4weekdelta_dose5+ num4weekdelta_notreported
# 1 NA                   NA
# 2 NA                   NA
# 3 NA                   NA
# 4 NA                   NA
# 5 NA                   NA
# 6 NA                   NA

# %%
data_canada<- data|>
filter(product_name=="Total")|>
filter(prename=="Canada")
head(data_canada)
# Out:
#   week_end   pruid prename prfname product_name numtotal_totaldoses_admin
# 1 2020-12-19 1     Canada  Canada  Total         12362
# 2 2020-12-26 1     Canada  Canada  Total         46156
# 3 2021-01-02 1     Canada  Canada  Total         82512
# 4 2021-01-09 1     Canada  Canada  Total        221866
# 5 2021-01-16 1     Canada  Canada  Total        591669
# 6 2021-01-23 1     Canada  Canada  Total        834796
#   numtotal_dose1_admin numtotal_dose2_admin numtotal_dose3_admin
# 1   7634                   0                NA
# 2  28940                   0                NA
# 3  54207                   0                NA
# 4 134067                4521                NA
# 5 419138               26748                NA
# 6 556675               59294                NA
#   numtotal_dose4_admin ⋯ num2weekdelta_dose3 num2weekdelta_dose4
# 1 NA                   ⋯ NA                  NA
# 2 NA                   ⋯ NA                  NA
# 3 NA                   ⋯ NA                  NA
# 4 NA                   ⋯ NA                  NA
# 5 NA                   ⋯ NA                  NA
# 6 NA                   ⋯ NA                  NA
#   num2weekdelta_dose5+ num2weekdelta_notreported num4weekdelta_dose1
# 1 NA                       NA                    NA
# 2 NA                       NA                    NA
# 3 NA                    23577                    NA
# 4 NA                       NA                    NA
# 5 NA                   117478                    NA
# 6 NA                       NA                    NA
#   num4weekdelta_dose2 num4weekdelta_dose3 num4weekdelta_dose4
# 1 NA                  NA                  NA
# 2 NA                  NA                  NA
# 3 NA                  NA                  NA
# 4 NA                  NA                  NA
# 5 NA                  NA                  NA
# 6 NA                  NA                  NA
#   num4weekdelta_dose5+ num4weekdelta_notreported
# 1 NA                   NA
# 2 NA                   NA
# 3 NA                   NA
# 4 NA                   NA
# 5 NA                   NA
# 6 NA                   NA

# %% [markdown]
# ## The original cleaned data

# %%
data2<-data_canada |>
select(- prename, - prfname, - pruid, - product_name)|>
    select(week_end:numtotal_dose5_admin)
head(data2)
tail(data2)
# Out:
#   week_end   numtotal_totaldoses_admin numtotal_dose1_admin
# 1 2020-12-19  12362                      7634
# 2 2020-12-26  46156                     28940
# 3 2021-01-02  82512                     54207
# 4 2021-01-09 221866                    134067
# 5 2021-01-16 591669                    419138
# 6 2021-01-23 834796                    556675
#   numtotal_dose2_admin numtotal_dose3_admin numtotal_dose4_admin
# 1     0                NA                   NA
# 2     0                NA                   NA
# 3     0                NA                   NA
# 4  4521                NA                   NA
# 5 26748                NA                   NA
# 6 59294                NA                   NA
#   numtotal_dose5_admin
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA
#   week_end   numtotal_totaldoses_admin numtotal_dose1_admin
# 1 2022-07-17 86009735                  32145203
# 2 2022-08-14 87302075                  32234633
# 3 2022-09-11 88341307                  32315056
# 4 2022-10-09 90338994                  32355613
# 5 2022-11-06 93124414                  32394311
# 6 2022-12-04 95220861                  32447425
#   numtotal_dose2_admin numtotal_dose3_admin numtotal_dose4_admin
# 1 30885006             18884973             4073823
# 2 30924720             19017046             5087688
# 3 30960216             19166636             5671411
# 4 30999153             19300924             6802853
# 5 31048407             19455019             8191321
# 6 31094617             19614995             9216264
#   numtotal_dose5_admin
# 1   20730
# 2   37988
# 3  227988
# 4  880451
# 5 2035356
# 6 2847560

# %% [markdown]
# Normilized to days data

# %%
newdata<- data2|>
    mutate(days=as.numeric(week_end)-18615)|>
    select(-week_end)

# %%
newnewdata <- newdata|>
#mutate(days=days)|>
mutate(total=as.vector(numtotal_totaldoses_admin))|>
mutate(dose1=as.vector(numtotal_dose1_admin))|>
mutate(dose2=as.vector(numtotal_dose2_admin))|>
mutate(dose3=as.vector(numtotal_dose3_admin))|>
mutate(dose4=as.vector(numtotal_dose4_admin))|>
mutate(dose5=as.vector(numtotal_dose5_admin))|>
select(-numtotal_totaldoses_admin,-numtotal_dose5_admin,-numtotal_dose4_admin,-numtotal_dose3_admin,-numtotal_dose2_admin,-numtotal_dose1_admin)
head(newnewdata)
# Out:
#   days total  dose1  dose2 dose3 dose4 dose5
# 1  0    12362   7634     0 NA    NA    NA
# 2  7    46156  28940     0 NA    NA    NA
# 3 14    82512  54207     0 NA    NA    NA
# 4 21   221866 134067  4521 NA    NA    NA
# 5 28   591669 419138 26748 NA    NA    NA
# 6 35   834796 556675 59294 NA    NA    NA

# %% [markdown]
# Using `newnewdata` to compelete the analysis

# %%
na_row_total<- nrow(newnewdata[is.na(newnewdata$total),])
na_row_total
na_row_1<- nrow(newnewdata[is.na(newnewdata$dose1),])
na_row_1
na_row_2<- nrow(newnewdata[is.na(newnewdata$dose2),])
na_row_2
na_row_3<- nrow(newnewdata[is.na(newnewdata$dose3),])
na_row_3
na_row_4<- nrow(newnewdata[is.na(newnewdata$dose4),])
na_row_4
na_row_5<- nrow(newnewdata[is.na(newnewdata$dose5),])
na_row_5
# Out:
# [1] 0
# [1] 0
# [1] 0
# [1] 16
# [1] 16
# [1] 16

# %% [raw]
# ggplot(newnewdata, aes(x=days,y=dose3))
#
# sa1<- nls(dose3~c*days^z, data=newnewdata, start=c(c=1750000, z=0.27))
# sa1
#
# ggplot(newnewdata, aes(x=days,y=dose3))
#
# #sa2<-lm(log(dose3)~log(days), data=newnewdata)
# #sa2

# %% [raw]
# newnewdata<-newnewdata|>
# mutate(days=as.factor(days))|>
# group_by(days)|>
# newnewdata

# %% [markdown]
# ## dose 1

# %%
options(repr.plot.width = 12, repr.plot.height = 7)

x<-newnewdata$days
y<-newnewdata$dose1
plot(y~x,xlim=c(0,1000))

bbb <- nls(y ~ height/(1 + exp((xmid - x)/scal)),
                           start = list(xmid = 100, scal = 10, height = 5000000))
#bbb
aaa<- coef(bbb)
earlyx<-c(0:1000)
ypred<-aaa[3]/(1 + exp((aaa[1] - earlyx)/aaa[2]))

plot1<- plot(ypred~earlyx)+
plot(y~x,xlim=c(0,1000))+
lines(x,predict(bbb))+
title("dose 1")

plot1
# Out:
# plot without title
# plot without title
# integer(0)
# Plot with title “dose 1”

# %% [markdown]
# ## the graph looks wired

# %% [markdown]
# ## dose 2

# %%
x<-newnewdata$days
y<-newnewdata$dose2
#plot(y~x)

options(repr.plot.width = 12, repr.plot.height = 7)
bbb<-nls(y ~ height/(1 + exp((xmid - x)/scal)),
                           start = list(xmid = 100, scal = 10, height = 5000000))
#bbb
aaa<- coef(bbb)
earlyx<-c(0:1000)
ypred<-aaa[3]/(1 + exp((coef(bbb)[1] - earlyx)/coef(bbb)[2]))
#ypred
plot2<-plot(ypred~earlyx)+
plot(y~x)+
lines(x,predict(bbb))+
title("dose 2")
plot2
#predict(bbb)
# Out:
# plot without title
# integer(0)
# Plot with title “dose 2”

# %% [markdown]
# ## dose 3

# %%
newnewdata3<-newnewdata|>filter(!is.na(dose3))

# %%
x<-newnewdata3$days
y<-newnewdata3$dose3
#plot(y~x)

options(repr.plot.width = 12, repr.plot.height = 7)
bbb<-nls(y ~ height/(1 + exp((xmid - x)/scal)),
                           start = list(xmid = 400, scal = 10, height = 5000000))
#bbb
aaa<- coef(bbb)
earlyx<-c(0:1000)
ypred<-aaa[3]/(1 + exp((coef(bbb)[1] - earlyx)/coef(bbb)[2]))
#ypred
plot3<-plot(ypred~earlyx)+
plot(y~x)+
lines(x,predict(bbb))+
title("dose 3")

plot3
# Out:
# plot without title
# integer(0)
# Plot with title “dose 3”

# %% [markdown]
# ## dose 4

# %%
newnewdata4<-newnewdata|>filter(!is.na(dose4))
head(newnewdata4)
# Out:
#   days total    dose1    dose2   dose3 dose4 dose5
# 1 112   8145392  5466319  803183 0     0     0
# 2 119  10129352  6870045  899865 0     0     0
# 3 126  12157691  8359605  968719 0     0     0
# 4 133  13908535  9670367 1019308 0     0     0
# 5 140  16031695 11233974 1078081 0     0     0
# 6 147  18652595 13139059 1188775 0     0     0

# %%
x<-newnewdata4$days
y<-newnewdata4$dose4 
#plot(y~x)

options(repr.plot.width = 12, repr.plot.height = 7)
bbb<-nls(y ~ height/(1 + exp((xmid - x)/scal)),
                           start = list(xmid = 600, scal = 10, height = 5000000))
#bbb
aaa<- coef(bbb)
earlyx<-c(0:1000)
ypred<-aaa[3]/(1 + exp((coef(bbb)[1] - earlyx)/coef(bbb)[2]))
#ypred
plot4<-plot(ypred~earlyx)+
plot(y~x)+
lines(x,predict(bbb))+
title("dose 4")
plot4
# Out:
# plot without title
# integer(0)
# Plot with title “dose 4”

# %% [markdown]
# ## dose 5+

# %%
newnewdata5<-newnewdata|>filter(!is.na(dose5))
head(newnewdata5)
nrow(newnewdata5)
#ggplot(newnewdata5, aes(x=days,y=dose5))+
#geom_point(aes(color=age))
# Out:
#   days total    dose1    dose2   dose3 dose4 dose5
# 1 112   8145392  5466319  803183 0     0     0
# 2 119  10129352  6870045  899865 0     0     0
# 3 126  12157691  8359605  968719 0     0     0
# 4 133  13908535  9670367 1019308 0     0     0
# 5 140  16031695 11233974 1078081 0     0     0
# 6 147  18652595 13139059 1188775 0     0     0
# [1] 63

# %% [markdown]
# ### only 63 days of data for this dose

# %%
x<-newnewdata5$days
y<-newnewdata5$dose5
#plot(y~x)

options(repr.plot.width = 12, repr.plot.height = 7)
bbb<-nls(y ~ height/(1 + exp((xmid - x)/scal)), 
                           start = list(xmid = 640, scal = 10, height = 5000000))
#bbb
aaa<- coef(bbb)
earlyx<-c(0:1000)
ypred<-aaa[3]/(1 + exp((coef(bbb)[1] - earlyx)/coef(bbb)[2]))
#ypred
plot5<-plot(ypred~earlyx)+
plot(y~x)
lines(x,predict(bbb))+
title("dose 5+")
plot5
# Out:
# plot without title
# integer(0)
# integer(0)
# Plot with title “dose 5+”

# %%
plot1
plot2
plot3
plot4
plot5
# Out:
# integer(0)
# integer(0)
# integer(0)
# integer(0)
# integer(0)

# %%
library(tidyverse)
